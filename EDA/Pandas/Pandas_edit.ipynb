# %%
import pandas as pd
import numpy as np
import seaborn as sn

# %%
df = sn.load_dataset("mpg")

# %% [markdown]
# ADDING COLUMNS AND ROWS

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.insert(df.columns.get_loc("name") + 1, "name-year", df.name + '-' + df.model_year.astype("string"))

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name                     name-year
# 0          70    usa  chevrolet chevelle malibu  chevrolet chevelle malibu-70
# 1          70    usa          buick skylark 320          buick skylark 320-70
# 2          70    usa         plymouth satellite         plymouth satellite-70
# 3          70    usa              amc rebel sst              amc rebel sst-70
# 4          70    usa                ford torino                ford torino-70

# %%
df1 = df[:1]

# %%
df = df.append(df1, ignore_index = True)

# %% [markdown]
# DROPPING DUPLICATES

# %%
df[df.duplicated()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 398  18.0          8         307.0       130.0    3504          12.0
#
#      model_year origin                       name  \
# 398          70    usa  chevrolet chevelle malibu
#
#                         name-year
# 398  chevrolet chevelle malibu-70

# %%
df.drop_duplicates(keep= "first", inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name, name-year]
# Index: []

# %% [markdown]
# DROPPING ROWS AND COLUMNS

# %%
df.drop("name-year", axis = 1, inplace= True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# Renaming columns

# %%
df.rename({"origin": "country"}, axis = 1, inplace= True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year country                       name
# 0          70     usa  chevrolet chevelle malibu
# 1          70     usa          buick skylark 320
# 2          70     usa         plymouth satellite
# 3          70     usa              amc rebel sst
# 4          70     usa                ford torino

# %% [markdown]
# Converting to different datatypes

# %% [markdown]
# A. TO CATEGORICAL

# %%
df["country"] = pd.Categorical(df["country"])

# %%
df.dtypes
# Out:
# mpg              float64
# cylinders          int64
# displacement     float64
# horsepower       float64
# weight             int64
# acceleration     float64
# model_year         int64
# country         category
# name              object
# dtype: object

# %% [markdown]
# B. TO NUMERIC

# %%
df["model_year"] = pd.to_numeric(df["model_year"], errors = "ignore")

# %%
df.dtypes
# Out:
# mpg              float64
# cylinders          int64
# displacement     float64
# horsepower       float64
# weight             int64
# acceleration     float64
# model_year         int64
# country         category
# name              object
# dtype: object

# %% [markdown]
# INDEXING, RESETTING INDEX AND SORTING

# %%
df.insert(df.columns.get_loc("name") + 1, "name-year", df.name + '-' + df.model_year.astype("string"))

# %%
df.set_index("name-year", inplace= True)

# %%
df.sort_index(ascending= True)
# Out:
#                              mpg  cylinders  displacement  horsepower  weight  \
# name-year
# amc ambassador brougham-73  13.0          8         360.0       175.0    3821
# amc ambassador dpl-70       15.0          8         390.0       190.0    3850
# amc ambassador sst-72       17.0          8         304.0       150.0    3672
# amc concord d/l-78          18.1          6         258.0       120.0    3410
# amc concord dl 6-79         20.2          6         232.0        90.0    3265
# ...                          ...        ...           ...         ...     ...
# vw pickup-82                44.0          4          97.0        52.0    2130
# vw rabbit c (diesel)-80     44.3          4          90.0        48.0    2085
# vw rabbit custom-79         31.9          4          89.0        71.0    1925
# vw rabbit-76                29.0          4          90.0        70.0    1937
# vw rabbit-80                41.5          4          98.0        76.0    2144
#
#                             acceleration  model_year country  \
# name-year
# amc ambassador brougham-73          11.0          73     usa
# amc ambassador dpl-70                8.5          70     usa
# amc ambassador sst-72               11.5          72     usa
# amc concord d/l-78                  15.1          78     usa
# amc concord dl 6-79                 18.2          79     usa
# ...                                  ...         ...     ...
# vw pickup-82                        24.6          82  europe
# vw rabbit c (diesel)-80             21.7          80  europe
# vw rabbit custom-79                 14.0          79  europe
# vw rabbit-76                        14.2          76  europe
# vw rabbit-80                        14.7          80  europe
#
#                                                name
# name-year
# amc ambassador brougham-73  amc ambassador brougham
# amc ambassador dpl-70            amc ambassador dpl
# amc ambassador sst-72            amc ambassador sst
# amc concord d/l-78                  amc concord d/l
# amc concord dl 6-79                amc concord dl 6
# ...                                             ...
# vw pickup-82                              vw pickup
# vw rabbit c (diesel)-80        vw rabbit c (diesel)
# vw rabbit custom-79                vw rabbit custom
# vw rabbit-76                              vw rabbit
# vw rabbit-80                              vw rabbit
#
# [398 rows x 9 columns]

# %%
df.reset_index(inplace= True)

# %%
df.drop("name-year", inplace= True, axis = 1)

# %%
df.sort_values(by = "mpg", ascending= False)
# Out:
#      index   mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322    322  46.6          4          86.0        65.0    2110          17.9
# 329    329  44.6          4          91.0        67.0    1850          13.8
# 325    325  44.3          4          90.0        48.0    2085          21.7
# 394    394  44.0          4          97.0        52.0    2130          24.6
# 326    326  43.4          4          90.0        48.0    2335          23.7
# ..     ...   ...        ...           ...         ...     ...           ...
# 103    103  11.0          8         400.0       150.0    4997          14.0
# 67      67  11.0          8         429.0       208.0    4633          11.0
# 25      25  10.0          8         360.0       215.0    4615          14.0
# 26      26  10.0          8         307.0       200.0    4376          15.0
# 28      28   9.0          8         304.0       193.0    4732          18.5
#
#      model_year country                  name
# 322          80   japan             mazda glc
# 329          80   japan   honda civic 1500 gl
# 325          80  europe  vw rabbit c (diesel)
# 394          82  europe             vw pickup
# 326          80  europe    vw dasher (diesel)
# ..          ...     ...                   ...
# 103          73     usa      chevrolet impala
# 67           72     usa       mercury marquis
# 25           70     usa             ford f250
# 26           70     usa             chevy c20
# 28           70     usa              hi 1200d
#
# [398 rows x 10 columns]

# %% [markdown]
# CONCAT
# df = pd.concat(df1, df2, ignore_index = True)
#
# MERGE
# df = pd.merge(df1, df2,  how = "inner", on = key)
